# %%
import uncertainpy as un
import chaospy as cp

from modello_HH import model_HH
# Out:
# /usr/local/lib/python3.8/dist-packages/uncertainpy-1.2.3-py3.8.egg/uncertainpy/plotting/plot_uncertainty.py:1818: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /usr/local/lib/python3.8/dist-packages/uncertainpy-1.2.3-py3.8.egg/uncertainpy/plotting/plot_uncertainty.py:1818: SyntaxWarning: "is" with a literal. Did you mean "=="?

# %%
# Initialize the model
model = un.Model(run=model_HH,
                 labels=["Time (ms)", "Membrane potential (mV)"])

# Define a parameter dictionary
parameters = {"V_0": -10,
              "E_R": 0.1,
              "C_m": 1,
              "gbar_Na": 120,
              "gbar_K": 36,
              "gbar_L": 0.3,
              "m_0": 0.0011,
              "n_0": 0.0003,
              "h_0": 0.9998,
              "E_Na": 112,
              "E_K": -12,
              "E_l": 10.613}

# Create the parameters
parameters = un.Parameters(parameters)

# Set all parameters to have a uniform distribution
# within a 20% interval around their fixed value
parameters.set_all_distributions(un.uniform(0.4))

# Perform the uncertainty quantification
UQ = un.UncertaintyQuantification(model,
                                  parameters=parameters)
# We set the seed to easier be able to reproduce the result
#import pdb; pdb.set_trace()
data = UQ.quantify(seed=10)
# Out:
# chaospy.orth_ttr name is to be deprecated; Use chaospy.expansion.stieltjes instead
# generating random samples using hammersley rule
# order: 3642, dim: 12 -> shape: (12, 3642)
# ...
# Calculating PC for each feature:   0%|          | 0/1 [00:00<?, ?it/s]poly shape: (1820,)
# parameter common shape: (3642,)
# output shape: (1820, 3642)
# Calculating PC for each feature:   0%|          | 0/1 [00:51<?, ?it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-2-6f7737f0a1d4> in <module>
#      29 # We set the seed to easier be able to reproduce the result
#      30 #import pdb; pdb.set_trace()
# ---> 31 data = UQ.quantify(seed=10)
#      32
#      33
#
# ...

# %%
n: execute the next line of code.

s: step into a function call.

c: continue execution until the next breakpoint.

l: list the current code context.

p <expression>: print the value of an expression.

q: quit the debugger.

# %%
#data=un.Data()
#data.load("data/model_HH.h5")
#data
dir(data)
# Out:
# ['_MutableMapping__marker',
#  '__abstractmethods__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_seed',
#  'add_features',
#  'backend',
#  'clear',
#  'data',
#  'data_information',
#  'error',
#  'get',
#  'get_labels',
#  'incomplete',
#  'items',
#  'keys',
#  'load',
#  'method',
#  'model_ignore',
#  'model_name',
#  'ndim',
#  'pop',
#  'popitem',
#  'remove_only_invalid_features',
#  'save',
#  'seed',
#  'setdefault',
#  'uncertain_parameters',
# ...
